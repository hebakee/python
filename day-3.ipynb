# %% [markdown]
# ![Screenshot%201446-01-14%20at%201.14.06%E2%80%AFAM.png](attachment:Screenshot%201446-01-14%20at%201.14.06%E2%80%AFAM.png)

# %%
# if a greater than b will print massage "a is greater than b"

# %%
# if a greater than b will print massage "a is greater than b"  if not will  print massage "b is greater than a" 
# if else

# %%
# if elif else

# %%
#  Traffic light example 
# if 
#red --stop

# %%
# if else 
# if green  -- go

# %%
# if elif else
# yallow -- get ready

# %% [markdown]
# ![Screenshot%201446-01-14%20at%201.15.05%E2%80%AFAM.png](attachment:Screenshot%201446-01-14%20at%201.15.05%E2%80%AFAM.png)

# %%
# print numbers from 1 to 5 using while

# %%
#Exit the loop when i is 3

# %%
#continue the loop when i is 3

# %%
# print the multiplication table 2 (1-10) using while and format

# %%
# using for to print the list items

# %%
#Use for to print the letters in the name Ragd

# %%
# using break with for

# %%
#Ask the user to enter five names and save them in the list

# %%
#Ask the user to enter five numbers and save them in the list and print the total of the numbers

# %% [markdown]
# ![Screenshot%201446-01-14%20at%201.19.44%E2%80%AFAM.png](attachment:Screenshot%201446-01-14%20at%201.19.44%E2%80%AFAM.png)

# %%
# function

# %%
# call function

# %%
# Arguments
# one Argument

# %%
# two Arguments

# %%
# A lambda function is a small anonymous function.

#lambda arguments : expression

#Add 10 to argument a, and return the result:

# %%
# create class

# %%
# calling the class

# %%
#Create a class named Person, use the __init__() function to assign values for name and age:

# %%
#Create a class named cat , use the __init__() function to assign values for name and age and create  function get_cat_info to print name and age :

# %% [markdown]
# # Questions

# %% [markdown]
# ## 1. Write a program that asks the user for their name and age, and then prints a message that says "Hello, [name]! You are [age] years old."

# %% [markdown]
# ## 2. Write a program that takes a list of numbers as input and returns the average of those numbers.

# %% [markdown]
# ## 3.Write a program that takes a list of integers as input and calculates the sum of all the even numbers in the list using a for loop.
