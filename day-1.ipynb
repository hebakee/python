# %% [markdown]
# ![Screenshot%201446-01-09%20at%206.25.33%E2%80%AFPM.png](attachment:Screenshot%201446-01-09%20at%206.25.33%E2%80%AFPM.png)

# %% [markdown]
# ![Screenshot%201446-01-09%20at%206.26.00%E2%80%AFPM.png](attachment:Screenshot%201446-01-09%20at%206.26.00%E2%80%AFPM.png)

# %% [markdown]
# #  1. Numbers

# %%
#Int, or integer, is a whole number, positive or negative, without decimals, of unlimited length.

# %%
#type

# %%
#float 
# Float, or "floating point number" is a number, positive or negative

# %% [markdown]
# ## Type Conversion

# %%
#convert from int to float:

# %%
#convert from float to int:

# %% [markdown]
# ![Screenshot%201446-01-09%20at%207.25.57%E2%80%AFPM.png](attachment:Screenshot%201446-01-09%20at%207.25.57%E2%80%AFPM.png)

# %% [markdown]
# ![Screenshot%201446-01-09%20at%207.28.55%E2%80%AFPM.png](attachment:Screenshot%201446-01-09%20at%207.28.55%E2%80%AFPM.png)

# %% [markdown]
# ![Screenshot%201446-01-09%20at%207.34.21%E2%80%AFPM.png](attachment:Screenshot%201446-01-09%20at%207.34.21%E2%80%AFPM.png)

# %% [markdown]
# ![Screenshot%201446-01-09%20at%207.34.56%E2%80%AFPM.png](attachment:Screenshot%201446-01-09%20at%207.34.56%E2%80%AFPM.png)

# %% [markdown]
# # 2. String

# %%
#Strings in python are surrounded by either single quotation marks '' , or double quotation marks "" .
#Strings are Arrays

# %%
#Get the character at position 1

# %%
#To get the length of a string, use the len() function.

# %%
# To check if a certain phrase or character is present in a string, we can use the keyword in.

# %%
#Check if "expensive" is NOT present in the following text:
txt = "The best things in life are free!"

# %% [markdown]
# ## Slicing Strings

# %%
#Get the characters from position 2 to position 5

# %%
#Get the characters from the start to position 5

# %%
#Get the characters from position 2, and all the way to the end

# %% [markdown]
# ##  methods can use it on strings

# %%
# The upper() method returns the string in upper case
a = "Hello, World!"

# %%
#The lower() method returns the string in lower case
a = "Hello, World!"

# %%
#The strip() method removes any whitespace from the beginning or the end:
a = " Hello, World! "

# %%
#The replace() method replaces a string with another string
a = "Hello, World! w"

# %%
#The split() method splits the string into substrings if it finds instances of the separator:

a = "Hello ,  World "

# %% [markdown]
# ## String Concatenation
# To concatenate, or combine, two strings you can use the + operator.

# %%
a = "Hello"
b = "World"

# %%
#To add a space between them:

a = "Hello"
b = "World"

# %% [markdown]
# ## Format - Strings

# %% [markdown]
# ![Screenshot%201446-01-09%20at%208.25.45%E2%80%AFPM.png](attachment:Screenshot%201446-01-09%20at%208.25.45%E2%80%AFPM.png)

# %% [markdown]
# # 3. Booleans

# %%
#Booleans represent one of two values: True or False.

# %% [markdown]
# # 4. List

# %%
#List items are ordered, changeable, and allow duplicate values

# %%
#Print the second item of the list

# %%
#Print the last item of the list

# %%
# Return the third, fourth, and fifth item
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

# %%
#Change the second item
thislist = ["apple", "banana", "cherry"]
thislist[1]='orange'
print(thislist)

# %%
# To add an item to the end of the list, use the append() method
thislist = ["apple", "banana", "cherry"]

# %%
#To insert a list item at a specified index, use the insert() method
thislist = ["apple", "banana", "cherry"]

# %%
# To append elements from another list to the current list, use the extend() method
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]

# %%
# Remove "banana"
thislist = ["apple", "banana", "cherry"]

# %%
thislist = ["apple", "banana", "cherry", "banana", "kiwi"]

# %%
# Remove Specified Index using pop()
thislist = ["apple", "banana", "cherry"]

# %%
# remove the last element 
thislist = ["apple", "banana", "cherry"]

# %%
# removes the specified index using del 
thislist = ["apple", "banana", "cherry"]

# %%
# Clear the list content
thislist = ["apple", "banana", "cherry"]

# %%
#Sort List Alphanumerically
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]

# %%
# Sort the list descending
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]

# %%
# Make a copy of a list with the copy() method
thislist = ["apple", "banana", "cherry"]

# %%
# Make a copy of a list with the list() method

thislist = ["apple", "banana", "cherry"]

# %%
#Join two list
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

# %%
#  min method
num_list=[22,50,60,11,20]

# %%
# max method

# %%
# sort method

# %%
# sum method

# %%
# range method  0 to 10

# %% [markdown]
# ## nested list

# %% [markdown]
# # 5. Tuple

# %%
# Tuple is a collection which is ordered and unchangeable.

# %%
#To determine how many items a tuple has, use the len() function

# %%
#Using the tuple() method to make a tuple

# %% [markdown]
# ## Change Tuple Values

# %%
# Convert the tuple into a list to be able to change it
x = ("apple", "banana", "cherry")

# %%
# Add item to the  tuple 
thistuple = ("apple", "banana", "cherry")

# %%
# using count
#  count Returns the number of times a specified value occurs in a tuple.

# %%
# using index
#  index Searches the tuple for a specified value and returns the position of where it was found
thistuple.index( "cherry")

# %% [markdown]
# # 6. set

# %%
# set
#A set is a collection which is unordered, unchangeable*, and unindexed.
# Set items are unchangeable, but you can remove items and add new items.


thisset={ 1,2,3}

type(thisset)

# %%
#Sets cannot have two items with the same value.

# %%
#True and 1 is considered the same value

# %%
#False and 0 is considered the same value:

# %%
#To determine how many items a set has, use the len() function.

# %%
# use the set() constructor to make a set.

# %%
#Check if "banana" is present in the set:

thisset = {"apple", "banana", "cherry"}

# %%
#Check if "banana" is NOT present in the set:

thisset = {"apple", "banana", "cherry"}

# %%
#Add an item to a set, using the add() method:

thisset = {"apple", "banana", "cherry"}

# %%
#To add items from another set into the current set, use the update() method.
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}

# %%
#Remove "banana" by using the remove() method:

thisset = {"apple", "banana", "cherry"}

# %%
#Remove "banana" by using the discard() method:

thisset = {"apple", "banana", "cherry"}

# %%
#The clear() method empties the set:

thisset = {"apple", "banana", "cherry"}

# %%
# Join set1 and set2 into a new set using union ():

set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

# %%
# Use | to join two sets:

set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

# %% [markdown]
# # 7. Dictionary

# %%
# Dictionaries are used to store data values in key:value pairs.

# %%
# Print the "brand" value of the dictionary:

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020,
    "year": 202

}

# %%
# Get the value of the "model" key

# %%
# There is also a method called get() that will give you the same result:

# %%
#keys()
#The keys() method will return a list of all the keys in the dictionary.

# %%
#Add a new item to the original dictionary, and see that the keys list gets updated as well
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.keys()

print(x) #before the change

# %%
#Get a list of the values:

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.values()

print(x) #before the change

car["year"] = 2020

print(x) #after the change

# %%
#Get a list of the key:value pairs items()

# %%
#Change the "year" to 2018:
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
#The update() method will update the dictionary with the items from the given argument.
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
#The pop() method removes the item with the specified key name
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
#The popitem() method removes the last inserted item
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
#The clear() method empties the dictionary:
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
#Make a copy of a dictionary with the copy() method:

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
#Make a copy of a dictionary with the dict() function:
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
